# %%
import numpy as np
import pandas as pd
import sys
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import normalize
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
# %matplotlib inline
from collections import Counter

# %%
enem = pd.read_csv("C:/Users/NB/Desktop/eleitorado/MyData.csv", delimiter = ',', encoding='iso-8859-1', decimal='.' )

# %%
enem
# Out:
#        Unnamed: 0  NU_ANO  NU_INSCRICAO SG_UF_RESIDENCIA  \
# 0               1    2015  1.500000e+11               SP
# 1               2    2015  1.500000e+11               RS
# 2               3    2015  1.500000e+11               PR
# 3               4    2015  1.500000e+11               BA
# 4               5    2015  1.500000e+11               SP
# 5               6    2015  1.500000e+11               SP
# 6               7    2015  1.500000e+11               PE
# 7               8    2015  1.500000e+11               RO
# 8               9    2015  1.500000e+11               DF
# 9              10    2015  1.500000e+11               ES
# 10             11    2015  1.500000e+11               SP
# 11             12    2015  1.500000e+11               RN
# 12             13    2015  1.500000e+11               MA
# 13             14    2015  1.500000e+11               MG
# 14             15    2015  1.500000e+11               PR
# ...

# %%
enem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 21 columns):
# Unnamed: 0                 30000 non-null int64
# NU_ANO                     30000 non-null int64
# NU_INSCRICAO               30000 non-null float64
# SG_UF_RESIDENCIA           30000 non-null object
# CO_MUNICIPIO_RESIDENCIA    30000 non-null int64
# NO_MUNICIPIO_RESIDENCIA    30000 non-null object
# CO_UF_RESIDENCIA           30000 non-null int64
# NU_IDADE                   30000 non-null int64
# TP_SEXO                    30000 non-null object
# TP_COR_RACA                30000 non-null int64
# TP_ST_CONCLUSAO            30000 non-null int64
# TP_ANO_CONCLUIU            30000 non-null int64
# TP_ESCOLA                  30000 non-null int64
# TP_ENSINO                  9397 non-null float64
# TP_DEPENDENCIA_ADM_ESC     9397 non-null float64
# NU_NOTA_CN                 30000 non-null float64
# NU_NOTA_CH                 30000 non-null float64
# ...

# %%
del enem['NU_INSCRICAO']

del enem['SG_UF_RESIDENCIA']
del enem['NO_MUNICIPIO_RESIDENCIA']
del enem['TP_SEXO']

# %%
enem
# Out:
#        Unnamed: 0  NU_ANO  CO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  \
# 0               1    2015                  3514403                35
# 1               2    2015                  4314902                43
# 2               3    2015                  4106902                41
# 3               4    2015                  2910800                29
# 4               5    2015                  3518800                35
# 5               6    2015                  3515707                35
# 6               7    2015                  2607901                26
# 7               8    2015                  1100122                11
# 8               9    2015                  5300108                53
# 9              10    2015                  3201308                32
# 10             11    2015                  3518800                35
# 11             12    2015                  2408904                24
# 12             13    2015                  2112233                21
# ...

# %%
plt.figure(figsize=(16,8))
sns.boxplot( x= 'NOTA_MEDIA', data=enem)

# %%
from sklearn.preprocessing import normalize
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score

# %%
X = enem.as_matrix()

# %%
X
# Out:
# array([[  1.00000000e+00,   2.01500000e+03,   3.51440300e+06, ...,
#           6.76300000e+02,   7.80000000e+02,   6.48700000e+02],
#        [  2.00000000e+00,   2.01500000e+03,   4.31490200e+06, ...,
#           4.15100000e+02,   6.20000000e+02,   4.86680000e+02],
#        [  3.00000000e+00,   2.01500000e+03,   4.10690200e+06, ...,
#           4.35500000e+02,   3.40000000e+02,   3.49572000e+02],
#        ...,
#        [  2.99980000e+04,   2.01700000e+03,   4.31340900e+06, ...,
#           4.76100000e+02,   5.40000000e+02,   4.04998000e+02],
#        [  2.99990000e+04,   2.01700000e+03,   2.92905700e+06, ...,
#           4.71800000e+02,   4.40000000e+02,   4.80460000e+02],
#        [  3.00000000e+04,   2.01700000e+03,   4.10690200e+06, ...,
#           3.69100000e+02,   2.80000000e+02,   3.95620000e+02]])

# %%
enem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 17 columns):
# Unnamed: 0                 30000 non-null int64
# NU_ANO                     30000 non-null int64
# CO_MUNICIPIO_RESIDENCIA    30000 non-null int64
# CO_UF_RESIDENCIA           30000 non-null int64
# NU_IDADE                   30000 non-null int64
# TP_COR_RACA                30000 non-null int64
# TP_ST_CONCLUSAO            30000 non-null int64
# TP_ANO_CONCLUIU            30000 non-null int64
# TP_ESCOLA                  30000 non-null int64
# TP_ENSINO                  9397 non-null float64
# TP_DEPENDENCIA_ADM_ESC     9397 non-null float64
# NU_NOTA_CN                 30000 non-null float64
# NU_NOTA_CH                 30000 non-null float64
# NU_NOTA_LC                 30000 non-null float64
# NU_NOTA_MT                 30000 non-null float64
# NU_NOTA_REDACAO            30000 non-null int64
# NOTA_MEDIA                 30000 non-null float64
# ...

# %%
enem['TP_ENSINO'].fillna(value=enem['TP_ENSINO'].median(), inplace=True)
enem['TP_DEPENDENCIA_ADM_ESC'].fillna(value=enem['TP_DEPENDENCIA_ADM_ESC'].median(), inplace=True)
enem['NU_NOTA_CN'].fillna(value=enem['NU_NOTA_CN'].median(), inplace=True)
enem['NU_NOTA_LC'].fillna(value=enem['NU_NOTA_LC'].median(), inplace=True)
enem['NU_NOTA_MT'].fillna(value=enem['NU_NOTA_MT'].median(), inplace=True)
enem['NU_NOTA_REDACAO'].fillna(value=enem['NU_NOTA_REDACAO'].median(), inplace=True)
enem['NOTA_MEDIA'].fillna(value=enem['NOTA_MEDIA'].median(), inplace=True)
enem['CO_MUNICIPIO_RESIDENCIA'].fillna(value=enem['CO_MUNICIPIO_RESIDENCIA'].median(), inplace=True)
enem['CO_UF_RESIDENCIA'].fillna(value=enem['CO_UF_RESIDENCIA'].median(), inplace=True)
enem['NU_IDADE'].fillna(value=enem['NU_IDADE'].median(), inplace=True)
enem['TP_COR_RACA'].fillna(value=enem['TP_COR_RACA'].median(), inplace=True)

enem['NU_ANO'].fillna(value=enem['NU_ANO'].median(), inplace=True)

# %%
enem
# Out:
#        Unnamed: 0  NU_ANO  CO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  \
# 0               1    2015                  3514403                35
# 1               2    2015                  4314902                43
# 2               3    2015                  4106902                41
# 3               4    2015                  2910800                29
# 4               5    2015                  3518800                35
# 5               6    2015                  3515707                35
# 6               7    2015                  2607901                26
# 7               8    2015                  1100122                11
# 8               9    2015                  5300108                53
# 9              10    2015                  3201308                32
# 10             11    2015                  3518800                35
# 11             12    2015                  2408904                24
# 12             13    2015                  2112233                21
# ...

# %%
del enem['TP_ENSINO']
del enem['TP_DEPENDENCIA_ADM_ESC']

# %%
enem
# Out:
#        Unnamed: 0  NU_ANO  CO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  \
# 0               1    2015                  3514403                35
# 1               2    2015                  4314902                43
# 2               3    2015                  4106902                41
# 3               4    2015                  2910800                29
# 4               5    2015                  3518800                35
# 5               6    2015                  3515707                35
# 6               7    2015                  2607901                26
# 7               8    2015                  1100122                11
# 8               9    2015                  5300108                53
# 9              10    2015                  3201308                32
# 10             11    2015                  3518800                35
# 11             12    2015                  2408904                24
# 12             13    2015                  2112233                21
# ...

# %%
enem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 15 columns):
# Unnamed: 0                 30000 non-null int64
# NU_ANO                     30000 non-null int64
# CO_MUNICIPIO_RESIDENCIA    30000 non-null int64
# CO_UF_RESIDENCIA           30000 non-null int64
# NU_IDADE                   30000 non-null int64
# TP_COR_RACA                30000 non-null int64
# TP_ST_CONCLUSAO            30000 non-null int64
# TP_ANO_CONCLUIU            30000 non-null int64
# TP_ESCOLA                  30000 non-null int64
# NU_NOTA_CN                 30000 non-null float64
# NU_NOTA_CH                 30000 non-null float64
# NU_NOTA_LC                 30000 non-null float64
# NU_NOTA_MT                 30000 non-null float64
# NU_NOTA_REDACAO            30000 non-null int64
# NOTA_MEDIA                 30000 non-null float64
# dtypes: float64(5), int64(10)
# memory usage: 3.4 MB

# %%
del enem['Unnamed: 0']

# %%
enem
# Out:
#        NU_ANO  CO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  NU_IDADE  \
# 0        2015                  3514403                35        21
# 1        2015                  4314902                43        23
# 2        2015                  4106902                41        19
# 3        2015                  2910800                29        17
# 4        2015                  3518800                35        27
# 5        2015                  3515707                35        22
# 6        2015                  2607901                26        17
# 7        2015                  1100122                11        20
# 8        2015                  5300108                53        20
# 9        2015                  3201308                32        17
# 10       2015                  3518800                35        37
# 11       2015                  2408904                24        18
# 12       2015                  2112233                21        26
# ...

# %%
enem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 14 columns):
# NU_ANO                     30000 non-null int64
# CO_MUNICIPIO_RESIDENCIA    30000 non-null int64
# CO_UF_RESIDENCIA           30000 non-null int64
# NU_IDADE                   30000 non-null int64
# TP_COR_RACA                30000 non-null int64
# TP_ST_CONCLUSAO            30000 non-null int64
# TP_ANO_CONCLUIU            30000 non-null int64
# TP_ESCOLA                  30000 non-null int64
# NU_NOTA_CN                 30000 non-null float64
# NU_NOTA_CH                 30000 non-null float64
# NU_NOTA_LC                 30000 non-null float64
# NU_NOTA_MT                 30000 non-null float64
# NU_NOTA_REDACAO            30000 non-null int64
# NOTA_MEDIA                 30000 non-null float64
# dtypes: float64(5), int64(9)
# memory usage: 3.2 MB

# %%
X = enem[[
    'NU_IDADE',
    'NU_ANO',
    'NU_NOTA_CN',
    'NU_NOTA_MT',
    'NOTA_MEDIA',
    'CO_UF_RESIDENCIA' 
    
    
]]

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
kmeans = KMeans(
    n_clusters = 3, # testar diferentes valores
    n_init = 15, 
    max_iter = 450, 
    init = 'k-means++'
)

# %%
dbscan.fit(X)
