# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import normalize
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fazenda = pd.read_csv("C:/Users/NB/Desktop/dados_fazenda/dados_fazenda_descricao.csv", delimiter = ',', encoding='utf-8', decimal='.' )

# %%
fazenda
# Out:
#                                               NAT_OPER
# 0                    [S] VENDA DE MERCADORIA P-REVENDA
# 1                       105 - Transf. Mercadoria Saida
# 2                       106 - Devolucao Troca/Impropia
# 3                                             1202.058
# 4                                             1202.064
# 5                  1-Transferencia de Mercadoria Lojas
# 6                                300-VENDA DE PRODUTOS
# 7                                      320-BONIFICACAO
# 8    5102 - VENDA DE MERCADORIA ADQUIRIDA OU RECEBI...
# 9    5102/6102 Venda de mercadoria adquirida ou rec...
# 10   5409 - TRANSFERENCIA DE MERCADORIA ADQUIRIDA O...
# 11   5927 - LANCAMENTO EFETUADO A TITULO DE BAIXA D...
# 12                                            5927.111
# 13   5949 - OUTRA SAIDA DE MERCADORIA OU PRESTACAO ...
# 14                        6.101 - VENDA FORA DO ESTADO
# 15                6.101-VENDA PRODUCAO ESTABELECIMENTO
# 16   6.101-VENDA PRODUCAO ESTABELECIMENTO /6.401-VE...
# 17              6.910 - REMESSA BONIF/DOACAO/BRINDE FO
# 18   6.910-REM.BONIFICACAO,DOACAO OU BRINDE/6.911-R...
# 19         6101 - Venda de producao do estabelecimento
# 20        6101AA - Venda producao do estabelecimento /
# 21   6102 - Venda de mercadoria adquirida ou recebi...
# 22           6102/AA-Venda merc.adq.receb.de terceiros
# 23                                           6102Venda
# 24                  6106 VENDA DE MERCADORIA ADQUIRIDA
# 25   6108 - Venda de mercadoria adquirida ou recebi...
# 26                                                6202
# 27   6403/AA-Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.t...
# 28                                                6411
# 29            6557-Transf. de Consumo deposito (Lj e D
# ..                                                 ...
# 633                               VENDAS MERC ADQ TERC
# 634                            Vendas Merc. Dent. Est.
# 635                        VENDAS MERC.COM SUBST.TRIB.
# 636                        VENDAS MERC.SEM SUBST.TRIB.
# 637                     VENDAS MERCAD OUT UF NAO CONTR
# 638     VENDAS MERCADORIAS ADIQ/RECEBIDAS DE TERCEIROS
# 639                        VENDAS PROD ESTABELECIMENTO
# 640                       VENDAS PROD.ESTAB. / REVENDA
# 641                             VENDAS PRODUCAO ESTAB.
# 642                  Vendas Produto do Estabelecimento
# 643                                      VENDAS SEM ST
# 644                               VENDAS SUB.TRIBUTARI
# 645                              VENDAS/ OUTRAS SAIDAS
# 646        VENDAS/ OUTRAS SAIDAS/ BONIF/DOAC.OU BRINDE
# 647                                       VENDAV MERC.
# 648                   VENDAV MERC./ VENDA DE MERC TERC
# 649                                VND COMERCIALIZACAO
# 650  Vnd mer.adq.rec.ter.op.mer.sj. / Venda merc.ad...
# 651  Vnd mer.adq.rec.ter.op.mer.sj. / Vnd merc.adq....
# 652  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.sub.
# 653  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...
# 654  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...
# 655  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...
# 656  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...
# 657  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...
# 658  Vnd merc.adq.rec.ter, obj qual.proc.ind.no estab.
# 659  Vnd prod.est.opr.c/pr.suj.reg.sub.trib.cnd.sub...
# 660  Vnd prod.est.opr.c/pr.suj.reg.sub.trib.cnd.sub...
# 661  Vnd.prod.est.prod.suj.reg.sub.trib.cont.sub.pr...
# 662  Vnd.prod.est.prod.suj.reg.sub.trib.cont.sub.pr...
#
# [663 rows x 1 columns]

# %%
fazenda = [e for e in fazenda['NAT_OPER'] if isinstance(e, str)]
fazenda = pd.DataFrame(fazenda)

# %%
vectorizer = TfidfVectorizer() # variar parametros (L1/L2, etc)
X = vectorizer.fit_transform(fazenda[0])
X = normalize(X)

# %%
kmeans = KMeans(
    n_clusters = 4, # variar
    n_init = 15, 
    max_iter = 450, 
    init = 'k-means++'
)

# %%
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=450,
#     n_clusters=4, n_init=15, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
fazenda['cluster'] = kmeans.labels_
fazenda
# Out:
#                                                      0  cluster
# 0                    [S] VENDA DE MERCADORIA P-REVENDA        0
# 1                       105 - Transf. Mercadoria Saida        3
# 2                       106 - Devolucao Troca/Impropia        3
# 3                                             1202.058        3
# 4                                             1202.064        3
# 5                  1-Transferencia de Mercadoria Lojas        0
# 6                                300-VENDA DE PRODUTOS        3
# 7                                      320-BONIFICACAO        3
# 8    5102 - VENDA DE MERCADORIA ADQUIRIDA OU RECEBI...        0
# 9    5102/6102 Venda de mercadoria adquirida ou rec...        0
# 10   5409 - TRANSFERENCIA DE MERCADORIA ADQUIRIDA O...        0
# 11   5927 - LANCAMENTO EFETUADO A TITULO DE BAIXA D...        3
# 12                                            5927.111        3
# 13   5949 - OUTRA SAIDA DE MERCADORIA OU PRESTACAO ...        3
# 14                        6.101 - VENDA FORA DO ESTADO        3
# 15                6.101-VENDA PRODUCAO ESTABELECIMENTO        3
# 16   6.101-VENDA PRODUCAO ESTABELECIMENTO /6.401-VE...        3
# 17              6.910 - REMESSA BONIF/DOACAO/BRINDE FO        1
# 18   6.910-REM.BONIFICACAO,DOACAO OU BRINDE/6.911-R...        1
# 19         6101 - Venda de producao do estabelecimento        3
# 20        6101AA - Venda producao do estabelecimento /        3
# 21   6102 - Venda de mercadoria adquirida ou recebi...        0
# 22           6102/AA-Venda merc.adq.receb.de terceiros        2
# 23                                           6102Venda        3
# 24                  6106 VENDA DE MERCADORIA ADQUIRIDA        0
# 25   6108 - Venda de mercadoria adquirida ou recebi...        0
# 26                                                6202        3
# 27   6403/AA-Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.t...        3
# 28                                                6411        3
# 29            6557-Transf. de Consumo deposito (Lj e D        3
# ..                                                 ...      ...
# 633                               VENDAS MERC ADQ TERC        2
# 634                            Vendas Merc. Dent. Est.        3
# 635                        VENDAS MERC.COM SUBST.TRIB.        3
# 636                        VENDAS MERC.SEM SUBST.TRIB.        3
# 637                     VENDAS MERCAD OUT UF NAO CONTR        3
# 638     VENDAS MERCADORIAS ADIQ/RECEBIDAS DE TERCEIROS        3
# 639                        VENDAS PROD ESTABELECIMENTO        3
# 640                       VENDAS PROD.ESTAB. / REVENDA        3
# 641                             VENDAS PRODUCAO ESTAB.        3
# 642                  Vendas Produto do Estabelecimento        3
# 643                                      VENDAS SEM ST        3
# 644                               VENDAS SUB.TRIBUTARI        3
# 645                              VENDAS/ OUTRAS SAIDAS        3
# 646        VENDAS/ OUTRAS SAIDAS/ BONIF/DOAC.OU BRINDE        3
# 647                                       VENDAV MERC.        3
# 648                   VENDAV MERC./ VENDA DE MERC TERC        2
# 649                                VND COMERCIALIZACAO        3
# 650  Vnd mer.adq.rec.ter.op.mer.sj. / Venda merc.ad...        2
# 651  Vnd mer.adq.rec.ter.op.mer.sj. / Vnd merc.adq....        2
# 652  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.sub.        3
# 653  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...        3
# 654  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...        3
# 655  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...        3
# 656  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...        3
# 657  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...        3
# 658  Vnd merc.adq.rec.ter, obj qual.proc.ind.no estab.        3
# 659  Vnd prod.est.opr.c/pr.suj.reg.sub.trib.cnd.sub...        3
# 660  Vnd prod.est.opr.c/pr.suj.reg.sub.trib.cnd.sub...        3
# 661  Vnd.prod.est.prod.suj.reg.sub.trib.cont.sub.pr...        3
# 662  Vnd.prod.est.prod.suj.reg.sub.trib.cont.sub.pr...        3
#
# [663 rows x 2 columns]

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import normalize
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
vectorizer = CountVectorizer() # variar parametros (L1/L2, etc)
X = vectorizer.fit_transform(fazenda[0])

# %%
# vetoriza
vectorizer = TfidfVectorizer() # variar parametros (L1/L2, etc)
X = vectorizer.fit_transform(fazenda[0])

# LSA
lsa = TruncatedSVD(n_components = 10)
X_reduced = lsa.fit_transform(X)

# %%
# clusteriza c/ DBSCAN
dbscan = DBSCAN(
    eps = 0.5, # variar
    min_samples = 5 # variar
)
dbscan.fit(X_reduced)
# Out:
# DBSCAN(algorithm='auto', eps=0.5, leaf_size=30, metric='euclidean',
#     metric_params=None, min_samples=5, n_jobs=1, p=None)

# %%
fazenda['dbscan'] = dbscan.labels_

# %%
fazenda
# Out:
#                                                      0  cluster  dbscan
# 0                    [S] VENDA DE MERCADORIA P-REVENDA        0       0
# 1                       105 - Transf. Mercadoria Saida        3       0
# 2                       106 - Devolucao Troca/Impropia        3       0
# 3                                             1202.058        3       0
# 4                                             1202.064        3       0
# 5                  1-Transferencia de Mercadoria Lojas        0       0
# 6                                300-VENDA DE PRODUTOS        3       0
# 7                                      320-BONIFICACAO        3       0
# 8    5102 - VENDA DE MERCADORIA ADQUIRIDA OU RECEBI...        0       0
# 9    5102/6102 Venda de mercadoria adquirida ou rec...        0       0
# 10   5409 - TRANSFERENCIA DE MERCADORIA ADQUIRIDA O...        0       0
# 11   5927 - LANCAMENTO EFETUADO A TITULO DE BAIXA D...        3       0
# 12                                            5927.111        3       0
# 13   5949 - OUTRA SAIDA DE MERCADORIA OU PRESTACAO ...        3       0
# 14                        6.101 - VENDA FORA DO ESTADO        3       0
# 15                6.101-VENDA PRODUCAO ESTABELECIMENTO        3       0
# 16   6.101-VENDA PRODUCAO ESTABELECIMENTO /6.401-VE...        3       0
# 17              6.910 - REMESSA BONIF/DOACAO/BRINDE FO        1       0
# 18   6.910-REM.BONIFICACAO,DOACAO OU BRINDE/6.911-R...        1       0
# 19         6101 - Venda de producao do estabelecimento        3       0
# 20        6101AA - Venda producao do estabelecimento /        3       0
# 21   6102 - Venda de mercadoria adquirida ou recebi...        0       0
# 22           6102/AA-Venda merc.adq.receb.de terceiros        2       0
# 23                                           6102Venda        3       0
# 24                  6106 VENDA DE MERCADORIA ADQUIRIDA        0       0
# 25   6108 - Venda de mercadoria adquirida ou recebi...        0       0
# 26                                                6202        3       0
# 27   6403/AA-Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.t...        3       0
# 28                                                6411        3       0
# 29            6557-Transf. de Consumo deposito (Lj e D        3       0
# ..                                                 ...      ...     ...
# 633                               VENDAS MERC ADQ TERC        2       0
# 634                            Vendas Merc. Dent. Est.        3       0
# 635                        VENDAS MERC.COM SUBST.TRIB.        3       0
# 636                        VENDAS MERC.SEM SUBST.TRIB.        3       0
# 637                     VENDAS MERCAD OUT UF NAO CONTR        3       0
# 638     VENDAS MERCADORIAS ADIQ/RECEBIDAS DE TERCEIROS        3       0
# 639                        VENDAS PROD ESTABELECIMENTO        3       0
# 640                       VENDAS PROD.ESTAB. / REVENDA        3       0
# 641                             VENDAS PRODUCAO ESTAB.        3       0
# 642                  Vendas Produto do Estabelecimento        3       0
# 643                                      VENDAS SEM ST        3       0
# 644                               VENDAS SUB.TRIBUTARI        3       0
# 645                              VENDAS/ OUTRAS SAIDAS        3       0
# 646        VENDAS/ OUTRAS SAIDAS/ BONIF/DOAC.OU BRINDE        3       0
# 647                                       VENDAV MERC.        3       0
# 648                   VENDAV MERC./ VENDA DE MERC TERC        2       0
# 649                                VND COMERCIALIZACAO        3       0
# 650  Vnd mer.adq.rec.ter.op.mer.sj. / Venda merc.ad...        2       0
# 651  Vnd mer.adq.rec.ter.op.mer.sj. / Vnd merc.adq....        2       0
# 652  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.sub.        3       0
# 653  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...        3       0
# 654  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...        3       0
# 655  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...        3       0
# 656  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...        3       0
# 657  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...        3       0
# 658  Vnd merc.adq.rec.ter, obj qual.proc.ind.no estab.        3       0
# 659  Vnd prod.est.opr.c/pr.suj.reg.sub.trib.cnd.sub...        3       0
# 660  Vnd prod.est.opr.c/pr.suj.reg.sub.trib.cnd.sub...        3       0
# 661  Vnd.prod.est.prod.suj.reg.sub.trib.cont.sub.pr...        3       0
# 662  Vnd.prod.est.prod.suj.reg.sub.trib.cont.sub.pr...        3       0
#
# [663 rows x 3 columns]

# %%
outliers = pd.DataFrame(fazenda)

# %%
print(outliers[dbscan.labels_==-1])
# Out:
# Empty DataFrame
# Columns: [0, cluster, dbscan]
# Index: []

# %%
from sklearn.metrics import silhouette_score
from collections import Counter

# %%
fazenda['cluster'].value_counts()
# Out:
# 3    431
# 0    103
# 2     88
# 1     41
# Name: cluster, dtype: int64

# %%
text = ['Vendas de mercadoria']

# %%
X_new = vectorizer.transform(text)
fazenda['coseno'] = cosine_similarity(X_new, X)[0]
print(fazenda.sort_values(by = 'coseno'))
# Out:
#                                                      0  cluster  dbscan  \
# 331                    TRANSF ENTRE FILIAIS(54/53)C/ST        3       0
# 350                   TRANSF. MERC. P/ COMERCIALIZACAO        3       0
# 349  TRANSF. MERC. ADQ./REC. TERC. C/MERC.SUJ. SUBS...        2       0
# 348                       Transf. merc. adq. rec. terc        2       0
# 347                             TRANSF. MERC. ADQ. 3 S        2       0
# 346                                    TRANSF. FILIAIS        3       0
# 342                                 TRANSF. ATIVO FIXO        3       0
# 341                     TRANSF PROD DO ESTABELECIMENTO        3       0
# 338                        TRANSF MERC RECDA TERCEIROS        3       0
# 336                            TRANSF MERC ADQREC TERC        2       0
# 335  Transf merc adq/rec terceiros, sujeita regime ...        2       0
# 334                           TRANSF MERC ADQ/REC TERC        2       0
# 355                         TRANSF. P/ COMERCIALIZACAO        3       0
# 333           TRANSF MERC ADQ 3OS/ TRANF MERC ADQ TERC        2       0
# 661  Vnd.prod.est.prod.suj.reg.sub.trib.cont.sub.pr...        3       0
# 330                    TRANSF ENTRE FILIAIS(51/56)C/ST        3       0
# 327                          TRANS TERC REG SUBST TRIB        3       0
# 326                TRANF. FILIAL/ MERC. COM C/ ST ANTE        3       0
# 325                                      TRANF. FILIAL        3       0
# 323                            TRANF ATIVO IMOBILIZADO        3       0
# 322                                    Simples Remessa        3       0
# 319                  SaidaPerda, Roubo ou Deterioracao        3       0
# 318                                SAIDA TRANSFERENCIA        3       0
# 316                           Saida Roubo Identificado        3       0
# 315                    Saida Perda ou Deterior. (Loja)        3       0
# 332             TRANSF MERC 3 EM OPER SUJ SUBST TRIBUT        3       0
# 356                               TRANSF.COMERCIALIZAC        3       0
# 357          TRANSF.COMERCIALIZAC/ TRANSF. USO/CONSUMO        3       0
# 360                             TRANSF.MERC. RECEB. ST        3       0
# 408                                 VEND PROD SUJ A ST        3       0
# ..                                                 ...      ...     ...
# 631                                   Vendas estaduais        3       0
# 301                        SAIDA - VENDA DE MERCADORIA        0       0
# 466             VENDA DE MERCADORIA/ VENDA DE PRODUCAO        0       0
# 495             VENDA DE PRODUCAO/ VENDA DE MERCADORIA        0       0
# 641                             VENDAS PRODUCAO ESTAB.        3       0
# 632                      VENDAS MERC ADQ REC TERCEIROS        2       0
# 445                      VENDA DE MERCADORIA ADQUIRIDA        0       0
# 639                        VENDAS PROD ESTABELECIMENTO        3       0
# 185                           ENTRADA DEVOLUCAO VENDAS        3       0
# 372                        TRANSFERENCIA DE MERCADORIA        0       0
# 329                  TRANSF DE MERCADORIA DE TERCEIROS        0       0
# 574                      VENDA MERCADORIA DE TERCEIROS        0       0
# 344                              TRANSF. DE MERCADORIA        0       0
# 359                               TRANSF.DE MERCADORIA        0       0
# 565                                   Venda Mercadoria        0       0
# 633                               VENDAS MERC ADQ TERC        2       0
# 118                            DEVOLUCAO DE MERCADORIA        0       0
# 622                               VENDAS DE MERC. ADQU        3       0
# 132                   DEVOLUCAO DE VENDA DE MERCADORIA        0       0
# 145                      DEVOLUCAO DE VENDAS - REVENDA        3       0
# 163                    DEVOLUCAO VENDAS DE MERCADORIAS        3       0
# 627              Vendas de Mercadoria Dentro do Estado        3       0
# 443                                VENDA DE MERCADORIA        0       0
# 626  Vendas de mercadoria adquiridas ou recebida de...        0       0
# 162                                   DEVOLUCAO VENDAS        3       0
# 629                             VENDAS DE MERCADORIAS*        3       0
# 628                              VENDAS DE MERCADORIAS        3       0
# 625                          Vendas de Mercadoria (JS)        3       0
# 143                                Devolucao de Vendas        3       0
# 619                                             VENDAS        3       0
#
#        coseno
# 331  0.000000
# 350  0.000000
# 349  0.000000
# 348  0.000000
# 347  0.000000
# 346  0.000000
# 342  0.000000
# 341  0.000000
# 338  0.000000
# 336  0.000000
# 335  0.000000
# 334  0.000000
# 355  0.000000
# 333  0.000000
# 661  0.000000
# 330  0.000000
# 327  0.000000
# 326  0.000000
# 325  0.000000
# 323  0.000000
# 322  0.000000
# 319  0.000000
# 318  0.000000
# 316  0.000000
# 315  0.000000
# 332  0.000000
# 356  0.000000
# 357  0.000000
# 360  0.000000
# 408  0.000000
# ..        ...
# 631  0.391516
# 301  0.394976
# 466  0.397436
# 495  0.397436
# 641  0.404068
# 632  0.407980
# 445  0.411657
# 639  0.422428
# 185  0.424844
# 372  0.427171
# 329  0.428309
# 574  0.437001
# 344  0.444661
# 359  0.444661
# 565  0.446569
# 633  0.448633
# 118  0.470262
# 622  0.477323
# 132  0.480152
# 145  0.502325
# 163  0.528448
# 627  0.550763
# 443  0.567898
# 626  0.569609
# 162  0.583978
# 629  0.598043
# 628  0.598043
# 625  0.599231
# 143  0.674545
# 619  0.757943
#
# [663 rows x 4 columns]

# %%
import nltk
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer
import re
import operator
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.corpus import words
from nltk.corpus import webtext
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
# If you would like to work with the raw text you can use 'moby_raw'
with open('C:/Users/NB/Desktop/dados_fazenda/dados_fazenda_descricao.csv',  encoding='utf-8',) as f:
    moby_raw = f.read()
    
# If you would like to work with the novel in nltk.Text format you can use 'text1'
moby_tokens = nltk.word_tokenize(moby_raw)
text1 = nltk.Text(moby_tokens)

# %%
texto = [w.lower() for w in webtext.words('C:/Users/NB/Desktop/dados_fazenda/dados_fazenda_descricao.csv')]

# %%
procurar = BigramCollocationFinder.from_words(moby_tokens)

# %%
procurar.nbest(BigramAssocMeasures.likelihood_ratio, 30)
# Out:
# [('adquirida', 'ou'),
#  ('VENDA', 'DE'),
#  ('Venda', 'de'),
#  ('de', 'mercadoria'),
#  ('DE', 'MERCADORIA'),
#  ('mercadoria', 'adquirida'),
#  ('ou', 'recebida'),
#  ('MERC', '.'),
#  ('do', 'estabelecimento'),
#  ('MERC', 'ADQ'),
#  ('DO', 'ESTADO'),
#  ('producao', 'do'),
#  ('OU', 'RECEBIDA'),
#  ('de', 'terceiros'),
#  ('ENTRE', 'FILIAIS'),
#  ('VENDA', 'MERC'),
#  ('DEVOLUCAO', 'DE'),
#  ('MERCADORIA', 'ADQUIRIDA'),
#  ('DE', 'MERCADORIAS'),
#  ('recebida', 'de'),
#  ('ADQUIRIDA', 'OU'),
#  ('OUTRAS', 'SAIDAS'),
#  ('REMESSA', 'EM'),
#  ('OU', 'BRINDE'),
#  ('de', 'Mercadoria'),
#  ('PRODUCAO', 'DO'),
#  ('DE', 'MERC'),
#  ('LANCAMENTO', 'EFETUADO'),
#  ('DOACAO', 'OU'),
#  (',', 'DOACAO')]

# %%
from nltk.corpus import stopwords
retira = set(stopwords.words('portuguese'))
filtra = lambda w: len(w) <3 or w in retira

# %%
procurar.apply_word_filter(filtra)

# %%
procurar.nbest(BigramAssocMeasures.likelihood_ratio, 30)
# Out:
# [('mercadoria', 'adquirida'),
#  ('MERC', 'ADQ'),
#  ('ENTRE', 'FILIAIS'),
#  ('VENDA', 'MERC'),
#  ('MERCADORIA', 'ADQUIRIDA'),
#  ('OUTRAS', 'SAIDAS'),
#  ('LANCAMENTO', 'EFETUADO'),
#  ('OUTRA', 'SAIDA'),
#  ('PARA', 'COMERCIALIZACAO'),
#  ('MERCADORIA/', 'VENDA'),
#  ('NAO', 'CONTRIBUINTE'),
#  ('IMP', 'ICMS'),
#  ('nao', 'contribuinte'),
#  ('PRODUTO', 'CST'),
#  ('DEVA', 'POR'),
#  ('POR', 'ELE'),
#  ('PRODUCAO', 'ESTABELECIMENTO'),
#  ('CUPOM', 'FISCAL'),
#  ('ESPECIFICADO', 'OUTRA'),
#  ('ESTOQUE', 'DECOR'),
#  ('VENDA', 'PROD'),
#  ('COMPRA', 'PARA'),
#  ('Vnd', 'mer.adq.rec.ter.op.mer.sj'),
#  ('Vnd', 'mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.sub'),
#  ('amostra', 'gratis'),
#  ('entrega', 'futura'),
#  ('merc.adq.receb.de', 'terceiros'),
#  ('NAO', 'DEVA'),
#  ('NAO', 'ESPECIFICADO'),
#  ('QUE', 'NAO')]

# %%
from nltk.collocations import TrigramCollocationFinder
from nltk.metrics import TrigramAssocMeasures

# %%
procurar2 = TrigramCollocationFinder.from_words(moby_tokens)

# %%
procurar2.nbest(TrigramAssocMeasures.likelihood_ratio, 30)
# Out:
# [('adquirida', 'ou', 'recebida'),
#  ('mercadoria', 'adquirida', 'ou'),
#  ('Venda', 'de', 'mercadoria'),
#  ('.', 'MERC', '.'),
#  ('VENDA', 'DE', 'MERCADORIA'),
#  ('de', 'mercadoria', 'adquirida'),
#  ('adquirida', 'ou', 'rec'),
#  ('VENDA', 'DE', 'MERCADORIAS'),
#  ('producao', 'do', 'estabelecimento'),
#  ('VENDA', 'DE', 'MERC'),
#  ('DEVOLUCAO', 'DE', 'MERCADORIA'),
#  ('adquirida', 'ou', 'receb'),
#  ('DE', 'MERCADORIA', 'ADQUIRIDA'),
#  ('VENDA', 'DE', 'PRODUCAO'),
#  ('adquirida', 'ou', 'receb.de'),
#  ('adquirida', 'ou', 'recebid'),
#  ('VENDA', 'MERC', '.'),
#  ('Venda', 'de', 'Mercadoria'),
#  ('merc', 'adquirida', 'ou'),
#  ('.', 'adquirida', 'ou'),
#  ('ou', 'recebida', 'de'),
#  ('VENDA', 'DE', 'MERCADORIA/'),
#  ('.', 'TRANSF', '.'),
#  ('DE', 'MERC', '.'),
#  ('.', 'merc', '.'),
#  ('MERCADORIA/', 'VENDA', 'DE'),
#  ('VENDA', 'MERC', 'ADQ'),
#  ('MERC', '.', 'TERC'),
#  ('.', 'rec', '.'),
#  ('ADQUIRIDA', 'OU', 'RECEBIDA')]

# %%
filtra2 = lambda w: len(w) <3 or w in retira

# %%
procurar2.apply_word_filter(filtra2)

# %%
procurar2.nbest(TrigramAssocMeasures.likelihood_ratio, 30)
# Out:
# [('VENDA', 'MERC', 'ADQ'),
#  ('MERC', 'ADQ', 'TERC'),
#  ('Transf', 'mercadoria', 'adquirida'),
#  ('MERCADORIA/', 'VENDA', 'MERC'),
#  ('MERC', 'ADQ', '3OS/'),
#  ('MERC', 'ADQ', 'TERCEIROS'),
#  ('VDA', 'MERC', 'ADQ'),
#  ('TRANSF', 'MERC', 'ADQ'),
#  ('TERCEIROS', 'VENDA', 'MERC'),
#  ('MERC', 'ADQ', 'TERC./'),
#  ('MERC', 'ADQ', 'TERC/'),
#  ('VENDAS', 'MERC', 'ADQ'),
#  ('TRANSFERENCIA', 'ENTRE', 'FILIAIS'),
#  ('TRANSF', 'ENTRE', 'FILIAIS'),
#  ('MERC', 'ADQ', 'TERCEI'),
#  ('VEN', 'MERC', 'ADQ'),
#  ('BONIF', 'MERC', 'ADQ'),
#  ('TRANF', 'MERC', 'ADQ'),
#  ('ANTERI', 'VENDA', 'MERC'),
#  ('SUBSTITUTO', 'VENDA', 'MERC'),
#  ('MERC', 'ADQ', 'REC'),
#  ('CONTRIBUINTE', 'VENDA', 'MERC'),
#  ('VENDA', 'MERC', 'ADQUIRIDA'),
#  ('ENTRE', 'FILIAIS', 'TRANSFERENCIA'),
#  ('TERC', 'VENDA', 'MERC'),
#  ('VENDA', 'MERC', 'ADQU'),
#  ('VENDAS/', 'OUTRAS', 'SAIDAS'),
#  ('VENDA', 'MERCADORIA', 'ADQUIRIDA'),
#  ('DO/', 'VENDA', 'MERC'),
#  ('REMESS', 'VENDA', 'MERC')]

# %%
fazenda[fazenda['cluster']==3]
# Out:
#                                                      0  cluster  dbscan  \
# 1                       105 - Transf. Mercadoria Saida        3       0
# 2                       106 - Devolucao Troca/Impropia        3       0
# 3                                             1202.058        3       0
# 4                                             1202.064        3       0
# 6                                300-VENDA DE PRODUTOS        3       0
# 7                                      320-BONIFICACAO        3       0
# 11   5927 - LANCAMENTO EFETUADO A TITULO DE BAIXA D...        3       0
# 12                                            5927.111        3       0
# 13   5949 - OUTRA SAIDA DE MERCADORIA OU PRESTACAO ...        3       0
# 14                        6.101 - VENDA FORA DO ESTADO        3       0
# 15                6.101-VENDA PRODUCAO ESTABELECIMENTO        3       0
# 16   6.101-VENDA PRODUCAO ESTABELECIMENTO /6.401-VE...        3       0
# 19         6101 - Venda de producao do estabelecimento        3       0
# 20        6101AA - Venda producao do estabelecimento /        3       0
# 23                                           6102Venda        3       0
# 26                                                6202        3       0
# 27   6403/AA-Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.t...        3       0
# 28                                                6411        3       0
# 29            6557-Transf. de Consumo deposito (Lj e D        3       0
# 33                     AJUSTE DE INVENTARIO - ENTRADAS        3       0
# 34                                AMOST.GRATIS/MAT.PRO        3       0
# 35                                             Amostra        3       0
# 36                                            AMOSTRAS        3       0
# 37                                 ANULACAO DE VALORES        3       0
# 38                                    ANULADO DE VENDA        3       0
# 39                      Baixa de Estoque - Perda/Roubo        3       0
# 40           BAIXA DE ESTOQUE DE MERCADORIAS AVARIADAS        3       0
# 41            BAIXA DE ESTOQUE DE MERCADORIAS VENCIDAS        3       0
# 42                 Baixa de estoque dec PERDA-AV-ROUBO        3       0
# 43   BAIXA DE ESTOQUE DECOR. DE ROUBO/ PERDA/DETERIOR.        3       0
# ..                                                 ...      ...     ...
# 628                              VENDAS DE MERCADORIAS        3       0
# 629                             VENDAS DE MERCADORIAS*        3       0
# 630             Vendas de prod estabel. suj ao icms st        3       0
# 631                                   Vendas estaduais        3       0
# 634                            Vendas Merc. Dent. Est.        3       0
# 635                        VENDAS MERC.COM SUBST.TRIB.        3       0
# 636                        VENDAS MERC.SEM SUBST.TRIB.        3       0
# 637                     VENDAS MERCAD OUT UF NAO CONTR        3       0
# 638     VENDAS MERCADORIAS ADIQ/RECEBIDAS DE TERCEIROS        3       0
# 639                        VENDAS PROD ESTABELECIMENTO        3       0
# 640                       VENDAS PROD.ESTAB. / REVENDA        3       0
# 641                             VENDAS PRODUCAO ESTAB.        3       0
# 642                  Vendas Produto do Estabelecimento        3       0
# 643                                      VENDAS SEM ST        3       0
# 644                               VENDAS SUB.TRIBUTARI        3       0
# 645                              VENDAS/ OUTRAS SAIDAS        3       0
# 646        VENDAS/ OUTRAS SAIDAS/ BONIF/DOAC.OU BRINDE        3       0
# 647                                       VENDAV MERC.        3       0
# 649                                VND COMERCIALIZACAO        3       0
# 652  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.sub.        3       0
# 653  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...        3       0
# 654  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...        3       0
# 655  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...        3       0
# 656  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...        3       0
# 657  Vnd mer.adq.rec.ter.op.mer.sj.rg.sub.trb.cnd.s...        3       0
# 658  Vnd merc.adq.rec.ter, obj qual.proc.ind.no estab.        3       0
# 659  Vnd prod.est.opr.c/pr.suj.reg.sub.trib.cnd.sub...        3       0
# 660  Vnd prod.est.opr.c/pr.suj.reg.sub.trib.cnd.sub...        3       0
# 661  Vnd.prod.est.prod.suj.reg.sub.trib.cont.sub.pr...        3       0
# 662  Vnd.prod.est.prod.suj.reg.sub.trib.cont.sub.pr...        3       0
#
#        coseno
# 1    0.164199
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 6    0.074046
# 7    0.000000
# 11   0.087611
# 12   0.000000
# 13   0.199142
# 14   0.000000
# 15   0.000000
# 16   0.000000
# 19   0.067695
# 20   0.000000
# 23   0.000000
# 26   0.000000
# 27   0.000000
# 28   0.000000
# 29   0.051084
# 33   0.058793
# 34   0.000000
# 35   0.000000
# 36   0.000000
# 37   0.069287
# 38   0.093029
# 39   0.072514
# 40   0.124351
# 41   0.124351
# 42   0.051341
# 43   0.102267
# ..        ...
# 628  0.598043
# 629  0.598043
# 630  0.280957
# 631  0.391516
# 634  0.306833
# 635  0.321082
# 636  0.295468
# 637  0.220695
# 638  0.331320
# 639  0.422428
# 640  0.336481
# 641  0.404068
# 642  0.332800
# 643  0.354755
# 644  0.325030
# 645  0.362467
# 646  0.233481
# 647  0.000000
# 649  0.000000
# 652  0.000000
# 653  0.000000
# 654  0.000000
# 655  0.000000
# 656  0.000000
# 657  0.000000
# 658  0.000000
# 659  0.000000
# 660  0.000000
# 661  0.000000
# 662  0.000000
#
# [431 rows x 4 columns]
