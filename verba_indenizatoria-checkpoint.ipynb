# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
verbas_palamentares = pd.read_csv("C:/Users/NB/Desktop/eleitorado/verba_indenizatoria_2017.csv", delimiter = ';', encoding='iso-8859-1', decimal=',' )

# %%
verbas_palamentares
# Out:
#       Gabinete                      Nome             CPF  \
# 0           16    Deputada Liliane Roriz  265.556.111-20
# 1           16    Deputada Liliane Roriz  265.556.111-20
# 2           16    Deputada Liliane Roriz  265.556.111-20
# 3           16    Deputada Liliane Roriz  265.556.111-20
# 4           16    Deputada Liliane Roriz  265.556.111-20
# 5           16    Deputada Liliane Roriz  265.556.111-20
# 6           16    Deputada Liliane Roriz  265.556.111-20
# 7           16    Deputada Liliane Roriz  265.556.111-20
# 8           16    Deputada Liliane Roriz  265.556.111-20
# 9           16    Deputada Liliane Roriz  265.556.111-20
# 10          16    Deputada Liliane Roriz  265.556.111-20
# 11          16    Deputada Liliane Roriz  265.556.111-20
# 12          16    Deputada Liliane Roriz  265.556.111-20
# 13          16    Deputada Liliane Roriz  265.556.111-20
# 14          16    Deputada Liliane Roriz  265.556.111-20
# ...

# %%
verbas_palamentares.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2718 entries, 0 to 2717
# Data columns (total 8 columns):
# Gabinete                     2718 non-null int64
# Nome                         2718 non-null object
# CPF                          2718 non-null object
# Empresa (ou Profissional)    2718 non-null object
# CNPJ (ou CPF)                2718 non-null object
# Data de Emissão              2685 non-null object
# Nº Documento                 2716 non-null object
# Valor                        2718 non-null float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 170.0+ KB

# %%
verbas_palamentares
verbas_palamentares['Valor'].fillna(value=votos['Valor'].median(), inplace=True)

# %%
verbas_palamentares
# Out:
#       Gabinete                      Nome             CPF  \
# 0           16    Deputada Liliane Roriz  265.556.111-20
# 1           16    Deputada Liliane Roriz  265.556.111-20
# 2           16    Deputada Liliane Roriz  265.556.111-20
# 3           16    Deputada Liliane Roriz  265.556.111-20
# 4           16    Deputada Liliane Roriz  265.556.111-20
# 5           16    Deputada Liliane Roriz  265.556.111-20
# 6           16    Deputada Liliane Roriz  265.556.111-20
# 7           16    Deputada Liliane Roriz  265.556.111-20
# 8           16    Deputada Liliane Roriz  265.556.111-20
# 9           16    Deputada Liliane Roriz  265.556.111-20
# 10          16    Deputada Liliane Roriz  265.556.111-20
# 11          16    Deputada Liliane Roriz  265.556.111-20
# 12          16    Deputada Liliane Roriz  265.556.111-20
# 13          16    Deputada Liliane Roriz  265.556.111-20
# 14          16    Deputada Liliane Roriz  265.556.111-20
# ...

# %%
import numpy as np
import pandas as pd
import sys
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import normalize
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
# %matplotlib inline

# %%
X = votos[[
    'Valor'
]]
kmeans = KMeans(
    n_clusters = 4, # testar diferentes valores
    n_init = 15, 
    max_iter = 450, 
    init = 'k-means++'
)
kmeans.fit(X)
verbas_palamentares
verbas_palamentares['cluster'] = kmeans.labels_ # adiciona coluna c/ cluster
grouped = verbas_palamentares.groupby('cluster')
stacked = pd.DataFrame()
for group in grouped:
    means = group[1].mean(axis = 0)
    
    stacked[group[0]] = means
print(stacked)
# Out:
#                    0            1            2            3
# Gabinete   12.560976    12.063348    10.253012    10.336100
# Valor     183.429057  5461.919593  8980.334578  2709.305768
# cluster     0.000000     1.000000     2.000000     3.000000

# %%
verbas_palamentares
# Out:
#       Gabinete                      Nome             CPF  \
# 0           16    Deputada Liliane Roriz  265.556.111-20
# 1           16    Deputada Liliane Roriz  265.556.111-20
# 2           16    Deputada Liliane Roriz  265.556.111-20
# 3           16    Deputada Liliane Roriz  265.556.111-20
# 4           16    Deputada Liliane Roriz  265.556.111-20
# 5           16    Deputada Liliane Roriz  265.556.111-20
# 6           16    Deputada Liliane Roriz  265.556.111-20
# 7           16    Deputada Liliane Roriz  265.556.111-20
# 8           16    Deputada Liliane Roriz  265.556.111-20
# 9           16    Deputada Liliane Roriz  265.556.111-20
# 10          16    Deputada Liliane Roriz  265.556.111-20
# 11          16    Deputada Liliane Roriz  265.556.111-20
# 12          16    Deputada Liliane Roriz  265.556.111-20
# 13          16    Deputada Liliane Roriz  265.556.111-20
# 14          16    Deputada Liliane Roriz  265.556.111-20
# ...

# %%
verbas_palamentares['cluster'].value_counts()
# Out:
# 0    2173
# 3     241
# 1     221
# 2      83
# Name: cluster, dtype: int64

# %%
sns.distplot(verbas_palamentares['Valor'], bins=50 )

# %%
##exploração de dados entre sim
sns.pairplot(verbas_palamentares, hue='Nome')

# %%
sns.set_style('ticks')
plt.figure(figsize=(16,8))
sns.barplot(x='Gabinete', y= 'Valor', data=verbas_palamentares)

# %%
plt.figure(figsize=(16,8))
sns.boxplot(x='Gabinete', y= 'Valor', data=verbas_palamentares)

# %%
sum(verbas_palamentares['Valor'])
# Out:
# 3003986.0300000007

# %%
verbas_palamentares[verbas_palamentares['cluster']==2]
# Out:
#       Gabinete                           Nome             CPF  \
# 30          24        Deputada Luzia de Paula  182.811.251-87
# 32          24        Deputada Luzia de Paula  182.811.251-87
# 41          24        Deputada Luzia de Paula  182.811.251-87
# 54          24        Deputada Luzia de Paula  182.811.251-87
# 64          24        Deputada Luzia de Paula  182.811.251-87
# 77          24        Deputada Luzia de Paula  182.811.251-87
# 85          24        Deputada Luzia de Paula  182.811.251-87
# 173          8          Deputada Telma Rufino  455.284.891-72
# 224          8          Deputada Telma Rufino  455.284.891-72
# 296          8          Deputada Telma Rufino  455.284.891-72
# 426         20  Deputado Bispo Renato Andrade  296.301.421-04
# 428         20  Deputado Bispo Renato Andrade  296.301.421-04
# 430         20  Deputado Bispo Renato Andrade  296.301.421-04
# 437         20  Deputado Bispo Renato Andrade  296.301.421-04
# ...
